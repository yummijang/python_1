# %%
# !pip show PILLOW
# Out:
# Name: Pillow
# Version: 10.1.0
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.org
# Author: Jeffrey A. Clark (Alex)
# Author-email: aclark@aclark.net
# License: HPND
# Location: C:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages
# Requires:
# Required-by:

# %%
from glob import glob #golb폴더에서 golb.py 를 실행
from PIL import Image
from PIL import ImageFilter

glob('./img/*.jpg')
fileList=glob('./img/*.jpg')
file=fileList[0]

img=Image.open(file).resize((400,300))
img_gray=img.convert("L")
img_gray#.show()
# Out:
# <PIL.Image.Image image mode=L size=400x300>
